# %% [markdown]
# El PCA no modela la secuencia temporal explícitamente (no tiene memoria), pero captura la varianza entre series completas.
#
# Es útil para reducción de dimensionalidad antes del clustering, especialmente si las series son largas.

# %% [markdown]
# Haz el padding como ya lo haces.
#
# Aplica PCA con n_components=0.95 para mantener la mayor parte de la información sin fijar un número.
#
# Luego, aplica KMeans en ese espacio reducido.
